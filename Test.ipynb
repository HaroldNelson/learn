# %%
print("Hello")
# Out:
# Hello

# %% [markdown]
# ## Hello
#
# It works

# %%
# %%bash
# ls
# Out:
# More Python.py
# README.md
# Test.ipynb
# Test.py
# Test2.py

# %%
x = 3
y = 4
z = x * y**2
print(z)
# Out:
# 48
